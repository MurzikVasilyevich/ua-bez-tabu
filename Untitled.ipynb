# %%
import argparse
import codecs
import json
import os
import shutil

import pandas as pd
from dict2xml import dict2xml


def main(source, destination):
    converter = Converter(source, destination)
#     converter.create_json()
#     converter.create_xml()


class Converter:
    def __init__(self, source, destination):
        self.source = source
        self.destination = destination
        self.dictionary = self.csv2dictionary()

    def csv2dictionary(self):
        os.makedirs(self.destination) if not os.path.exists(self.destination) else None
        shutil.copy(self.source, self.destination)
        df = pd.read_csv(self.source, encoding='utf-8')
        print(df.to_dict('index'))
#         dictionary = {
#             k: f.groupby('term')['synonym'].apply(list).to_dict()
#             for k, f in df.groupby('group')
#         }
#         print(dictionary)
#         return dictionary

#     def create_xml(self):
#         xml = dict2xml(self.dictionary)
#         with codecs.open(self.destination + "synonyms.xml", "w", "utf-8") as outfile:
#             outfile.write(xml)

#     def create_json(self):
#         json_object = json.dumps(self.dictionary, indent=4, ensure_ascii=False)
#         print(json_object)
#         with codecs.open(self.destination + "synonyms.json", "w", "utf-8") as outfile:
#             outfile.write(json_object)


if __name__ == '__main__':
#     parser = argparse.ArgumentParser(description='Convert CSV to JSON')
#     parser.add_argument('source', type=str, help='Source CSV file')
#     parser.add_argument('destination', type=str, help='Destination JSON file')
#     args = parser.parse_args()
    main("./synonyms.csv", "./data")
    print('Done!')
# Out:
# {0: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'агрегат', 'isWord': 1}, 1: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'антена', 'isWord': 1}, 2: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'апарат', 'isWord': 1}, 3: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'аргумент', 'isWord': 1}, 4: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'багатство', 'isWord': 1}, 5: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'балда', 'isWord': 1}, 6: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'банан', 'isWord': 1}, 7: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'бандура', 'isWord': 1}, 8: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'бен', 'isWord': 1}, 9: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'бидло', 'isWord': 1}, 10: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'біда', 'isWord': 1}, 11: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'бобик', 'isWord': 1}, 12: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'болванка', 'isWord': 1}, 13: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'болт', 'isWord': 1}, 14: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'бомко', 'isWord': 1}, 15: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'брехунець', 'isWord': 1}, 16: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'буйок', 'isWord': 1}, 17: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'булава', 'isWord': 1}, 18: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'бурулька', 'isWord': 1}, 19: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'буц', 'isWord': 1}, 20: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'вабик', 'isWord': 1}, 21: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'валек', 'isWord': 1}, 22: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'варган', 'isWord': 1}, 23: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': "вар'ят", 'isWord': 1}, 24: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'васильок', 'isWord': 1}, 25: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'вася', 'isWord': 1}, 26: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'взацний член тіла', 'isWord': 0}, 27: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'визволювач', 'isWord': 1}, 28: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'викрутас', 'isWord': 1}, 29: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'вимагач', 'isWord': 1}, 30: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'вискочка', 'isWord': 1}, 31: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'відкривач', 'isWord': 1}, 32: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'відросток', 'isWord': 1}, 33: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'вламувач', 'isWord': 1}, 34: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'воловий ріг', 'isWord': 0}, 35: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'волохач', 'isWord': 1}, 36: {'group': 'Частини тіла людини', 'term': 'Чоловічий статевий орган', 'synonym': 'воробч ...
# Done!

# %%
import argparse
import codecs
import json
import os
import shutil

import pandas as pd
from dict2xml import dict2xml

df = pd.read_csv("./synonyms.csv", encoding='utf-8')

j = (df.groupby(['group','term'])
       .apply(lambda x: x[['synonym']].to_dict('records'))
       .reset_index()
#        .rename(columns={0:'Tide-Data'})
       .to_json(orient='records'))


# df.groupby(['group','term']).groups

# dictionary = {
#     k: f.groupby('term')['synonym'].apply(list).to_dict()
#     for k, f in df.groupby('group')
# }

# dictionary
# Out:
# '"[{\\"group\\":\\"\\\\u0412\\\\u0435\\\\u043d\\\\u0435\\\\u0440\\\\u0438\\\\u0447\\\\u043d\\\\u0456 \\\\u0445\\\\u0432\\\\u043e\\\\u0440\\\\u043e\\\\u0431\\\\u0438\\",\\"term\\":\\"\\\\u0413\\\\u043e\\\\u043d\\\\u043e\\\\u0440\\\\u0435\\\\u044f\\",\\"0\\":[{\\"synonym\\":\\"\\\\u0437\\\\u0431\\\\u0443\\\\u0440\\"},{\\"synonym\\":\\"\\\\u0442\\\\u0440\\\\u0438\\\\u043d\\\\u044f\\"},{\\"synonym\\":\\"\\\\u0442\\\\u0440\\\\u0438\\\\u043f\\\\u0430\\\\u043a\\"},{\\"synonym\\":\\"\\\\u0442\\\\u0440\\\\u0438\\\\u043f\\\\u0435\\\\u043b\\\\u044c\\"},{\\"synonym\\":\\"\\\\u0442\\\\u0440\\\\u0438\\\\u043f\\\\u0435\\\\u0440\\"},{\\"synonym\\":\\"\\\\u0442\\\\u0440\\\\u0438 \\\\u043f\\\\u0435\\\\u0440\\\\u0430\\"},{\\"synonym\\":\\"\\\\u0444\\\\u0440\\\\u0430\\\\u043d\\\\u0446\\\\u0443\\\\u0437\\\\u044c\\\\u043a\\\\u0438\\\\u0439 \\\\u043d\\\\u0430\\\\u0441\\\\u043c\\\\u043e\\\\u0440\\\\u043a\\"}]},{\\"group\\":\\"\\\\u0412\\\\u0435\\\\u043d\\\\u0435\\\\u0440\\\\u0438\\\\u0447\\\\u043d\\\\u0456 \\\\u0445\\\\u0432\\\\u043e\\\\u0440\\\\u043e\\\\u0431\\\\u0438\\",\\"term\\":\\"\\\\u0421\\\\u0438\\\\u0444\\\\u0456\\\\u043b\\\\u0456\\\\u0441\\",\\"0\\":[{\\"synonym\\":\\"\\\\u0431\\\\u0443\\\\u043a\\\\u0435\\\\u0442 \\\\u0432\\\\u0435\\\\u043d\\\\u0435\\\\u0440\\\\u0438\\"},{\\"synonym\\":\\"\\\\u0432\\\\u0435\\\\u043d\\\\u0435\\\\u0440\\\\u0430\\"},{\\"synonym\\":\\"\\\\u0432\\\\u0435\\\\u043d\\\\u0435\\\\u0440\\\\u043a\\\\u0430\\"},{\\"synonym\\":\\"\\\\u0433\\\\u0435\\\\u043d\\\\u0435\\\\u0440\\\\u0430\\\\u043b \\\\u0441\\\\u0456\\\\u0444\\\\u0456\\\\u043b\\\\u0456\\\\u0441\\"},{\\"synonym\\":\\"\\\\u043b\\\\u044e\\\\u0454\\\\u0441\\"},{\\"synonym\\":\\"\\\\u043b\\\\u044e\\\\u0457\\\\u0441\\"},{\\"synonym\\":\\"\\\\u043f\\\\u043e\\\\u0433\\\\u0430\\\\u043d\\\\u0430 \\\\u0445\\\\u0432\\\\u043e\\\\u0440\\\\u043e\\\\u0431\\\\u0430\\"},{\\"synonym\\":\\"\\\\u043f\\\\u